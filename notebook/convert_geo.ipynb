# %%
# 事前にgeopandasを pip install または conda install してください
import geopandas as gpd

# 事前に国土数値情報ダウンロードサイトから行政区域データ「全国」データをダウンロードしてください
# https://nlftp.mlit.go.jp/ksj/gml/datalist/KsjTmplt-N03-v3_1.html
gdf = gpd.read_file('N03-20220101_GML/N03-22_220101.shp', rows=47)

gdf
# Out:
#    N03_001  N03_002  N03_003  N03_004  N03_007  \
# 0      北海道      NaN      NaN      NaN      NaN
# 1      青森県      NaN      NaN      NaN      NaN
# 2      岩手県      NaN      NaN      NaN      NaN
# 3      宮城県      NaN      NaN      NaN      NaN
# 4      秋田県      NaN      NaN      NaN      NaN
# 5      山形県      NaN      NaN      NaN      NaN
# 6      福島県      NaN      NaN      NaN      NaN
# 7      茨城県      NaN      NaN      NaN      NaN
# 8      栃木県      NaN      NaN      NaN      NaN
# 9      群馬県      NaN      NaN      NaN      NaN
# 10     埼玉県      NaN      NaN      NaN      NaN
# 11     千葉県      NaN      NaN      NaN      NaN
# 12     東京都      NaN      NaN      NaN      NaN
# 13    神奈川県      NaN      NaN      NaN      NaN
# 14     新潟県      NaN      NaN      NaN      NaN
# 15     富山県      NaN      NaN      NaN      NaN
# 16     石川県      NaN      NaN      NaN      NaN
# 17     福井県      NaN      NaN      NaN      NaN
# 18     山梨県      NaN      NaN      NaN      NaN
# ...

# %%
gdf = gdf[['N03_001', 'geometry']]

gdf
# Out:
#    N03_001                                           geometry
# 0      北海道  MULTIPOLYGON (((139.79936 41.35187, 139.79940 ...
# 1      青森県  MULTIPOLYGON (((139.93600 40.42836, 139.93587 ...
# 2      岩手県  MULTIPOLYGON (((141.71763 38.93417, 141.71762 ...
# 3      宮城県  MULTIPOLYGON (((141.50558 38.24465, 141.50556 ...
# 4      秋田県  MULTIPOLYGON (((139.87835 39.12636, 139.87785 ...
# 5      山形県  MULTIPOLYGON (((139.54718 38.55309, 139.54719 ...
# 6      福島県  MULTIPOLYGON (((140.79369 36.86217, 140.79366 ...
# 7      茨城県  MULTIPOLYGON (((140.84152 35.75027, 140.84133 ...
# 8      栃木県  POLYGON ((139.95784 37.15419, 139.95797 37.154...
# 9      群馬県  POLYGON ((139.10834 37.05541, 139.10849 37.055...
# 10     埼玉県  MULTIPOLYGON (((139.26272 36.24473, 139.26316 ...
# 11     千葉県  MULTIPOLYGON (((139.89894 34.89797, 139.89891 ...
# 12     東京都  MULTIPOLYGON (((136.07396 20.42276, 136.07388 ...
# 13    神奈川県  MULTIPOLYGON (((139.63160 35.12850, 139.63159 ...
# ...

# %%
gdf['geometry'] = gdf['geometry'].simplify(tolerance=0.001)
# Out:
# /home/sika/.local/share/virtualenvs/pandas-plotly-handbook-XgTgJsv2/lib/python3.9/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
gdf.to_file('todofuken.geojson', driver='GeoJSON', encoding='utf-8')
